# %% [markdown]
# # 🧠 BCI, 두뇌와 컴퓨터의 결합

# %% [markdown]
# 목차
# 1. BCI(Brain-Computer Interface)란 무엇인가?
# 2. 브레인투쿼티(Brain2QWERTY) 기술과 작동 원리
# 3. 브레인투쿼티의 특징 및 한계점
# 4. BCI 시스템의 향후 전망

# %% [markdown]
# ### 1. BCI(Brain-Computer Interface)란 무엇인가?

# %% [markdown]
# ![image.png](attachment:057fa8d1-d8a1-443a-8387-f7fe32128f64.png)

# %% [markdown]
# 뇌·컴퓨터 인터페이스(BCI, Brain-Computer Interface)란 인간의 뇌에서 발생하는 신경 신호를 감지하여 이를 디지털 신호로 변환하고, 이를 통해 외부 기기를 제어하거나 의사소통을 가능하게 하는 기술입니다. 인간의 뇌는 뉴런 사이에서 전기적 신호를 주고받으며 정보를 처리하는데, BCI는 이러한 신호를 분석하여 사용자의 의도를 해석하고 기계와 상호작용할 수 있도록 합니다.
#
# BCI는 신호를 감지하는 방식에 따라 침습적 BCI와 비침습적 BCI로 구분됩니다. 침습적 BCI는 두개골을 절개하고 뇌에 직접 전극을 삽입하여 뉴런의 활동을 정밀하게 측정하는 방식으로, 높은 신호 정확도를 가지지만 외과적 수술이 필요하고 감염 등의 위험이 존재합니다. 반면, 비침습적 BCI는 두피에 부착된 전극을 이용해 뇌파(EEG)를 측정하는 방식으로, 상대적으로 안전하지만 신호의 정확도가 낮고 외부 노이즈에 영향을 받을 가능성이 큽니다.
#
# BCI는 일반적인 입력 장치 없이도 사용자의 생각을 분석하여 컴퓨터, 로봇, 보조 기기 등과 연결할 수 있도록 하며, 이를 통해 신체 움직임이 제한된 사람들에게 의사소통과 기기 제어의 새로운 가능성을 제공합니다. 뇌에서 발생하는 신경 신호는 복잡하고 개별적인 차이가 크기 때문에, BCI는 신호를 효과적으로 분석하고 해석하기 위해 다양한 알고리즘과 신경과학적 기법을 활용하여 사용자 의도를 파악합니다.

# %% [markdown]
# ### 2. 브레인투쿼티(Brain2QWERTY) 기술과 작동 원리

# %% [markdown]
# ![image.png](attachment:ef1a4dc8-b0b9-4b56-8155-0520250e61ff.png)

# %% [markdown]
# - Brain2Qwerty의 정의
# Brain2Qwerty는 메타 AI 연구팀이 개발한 비침습적 뇌-컴퓨터 인터페이스(BCI) 기술로,
# 인간의 뇌 활동을 해석하여 생각만으로 타이핑할 수 있도록 설계된 시스템입니다.
# 이 기술은 전자뇌파(EEG) 및 자기뇌파(MEG) 데이터를 활용하여 사용자가 머릿속으로 입력하려는 문장을
# 실시간으로 해독하는 딥러닝 모델을 기반으로 합니다. 기존의 침습적 BCI 기술은 두개골을 절개하고
# 뇌에 전극을 삽입하는 방식이어서 위험성과 비용이 컸지만, Brain2Qwerty는 이러한 절차 없이도
# 뇌 신호를 감지하고 문장 입력을 가능하게 한다는 점에서 혁신적인 기술로 평가됩니다.
# 특히, 본 연구에서는 건강한 참가자 35명을 대상으로 실험을 진행하여, 비침습적 방식으로도
# 상당한 수준의 정확도를 달성할 수 있음을 입증하였습니다.
#
# - Brain2Qwerty의 작동 원리
# Brain2Qwerty는 뇌의 언어 및 운동 관련 신호를 해독하는 세 단계의 딥러닝 모델을 통해 작동합니다.
# 첫 번째 단계는 컨볼루션 모듈(Convolutional Module)로, EEG 및 MEG 데이터를 500ms 단위의 창(window)으로 나누어
# 신경 신호 패턴을 분석하는 역할을 합니다. 두 번째 단계는 트랜스포머 모듈(Transformer Module)로, 문장 수준에서
# 뇌 신호를 처리하고, 키 입력 패턴을 예측하는 기능을 수행합니다. 마지막으로 사전 학습된
# 언어 모델(Language Model)이 출력된 문장을 정제하고 오류를 보정하여 최종적으로 정확한 문장을 생성합니다.
# 특히, MEG 데이터를 활용할 경우 평균 문자 오류율(Character Error Rate, CER)은 32%, 일부 참가자의 경우 19%까지
# 낮출 수 있어 EEG 기반 모델(CER: 67%)보다 뛰어난 성능을 보였습니다.
# 이러한 과정은 뇌 신호에서 개별 문자, 음절, 단어를 순차적으로 해석하는 방식으로 진행되며,
# 신경망이 운동 과정과 언어적 요소를 모두 고려하여 최적의 문장을 예측할 수 있도록 설계되었습니다.

# %% [markdown]
# - 뉴스에 있는 파일을 확인해보면 타이핑 프로토콜이 예상한 뇌 반응을 유도하는지 확인하기 위한 실험에 대해 설명합니다.
#   실험에서는 왼손과 오른손 키 누름에 의해 유발된 뇌 반응을 비교하여 그 차이를 분석합니다. 각 피험자마다 선형 릿지 분류기를 훈련시켜 왼손과 오른손 반응을 분류하고, 그 결과 MEG가 EEG보다 더 높은 분류 정확도를 보였습니다. 또한, 문자 단위로도 분류를 반복한 결과, MEG가 더 높은 성능을 보였음을 확인할 수 있었습니다. 이 실험은 제시된 프로토콜이 예상된 뇌 반응을 유도한다는 것을 증명합니다.

# %% [markdown]
# ![image.png](attachment:2ecf893b-c3fc-4c42-93aa-ed91d2beb356.png)

# %% [markdown]
# A는 왼손과 오른손 키 누름에 따른 EEG 유발 반응의 차이를 보여주며,
# 각 검은 선은 키 누름에 대한 센서의 전압 차이를 나타냅니다.
# B는 MEG에 대한 동일한 차이를 나타냅니다.
# C는 선형 분류기를 훈련시켜 각 시간 샘플에서 왼손과 오른손을 예측하는 성능을 보여주며,
# 회색 선은 기회 수준을 나타내고, 오차 막대는 참가자 간 평균의 표준 오차를 나타냅니다.
# 통계적으로 유의미한 디코딩 점수는 별표로 표시됩니다.
# D는 문자 분류에 대한 동일한 성능을 나타냅니다.
# E-H는 기존 아키텍처(선형 모델과 EEGNet)와 우리의 세 단계 Brain2Qwerty 모델(Conv+Trans+Language Model)을 비교하며,
# 손 오류율(HER)과 문자 오류율(CER)에 대한 성능을 보여줍니다.
# 각 점은 한 참가자의 평균 점수를 나타내며, 통계적 유의미성은 p < 0.05(), p < 0.01(), p < 0.001()로 표시됩니다.

# %% [markdown]
# ![image.png](attachment:db59ee10-a7dc-4f0c-97b6-66274796c493.png)

# %% [markdown]
# A는 세 명의 대표적인 피험자에 대한 문자 오류율을 나타냅니다.
# 각 점은 고유한 문장을 나타내며, 오차 막대는 반복 측정 간 평균의 표준 오차를 나타냅니다.
# 흰 점은 아래에 표시된 문장을 나타냅니다.
# B는 두 문장에 대한 디코딩 예측을 나타냅니다. 여러 개의 분할 시드를 사용하여 문장별 예측을 얻었습니다.

# %% [markdown]
# ![image.png](attachment:d5f1c3e7-f7d3-4271-80ea-264ab8c03fec.png)

# %% [markdown]
# A는 형용사(ADJ), 명사, 동사, 관사(DET), 전치사(ADP) 등 다양한 품사 범주에 따라 문자 오류율(CER)을 평가하여
# 성능이 어떻게 달라지는지 분석한 것입니다.
# B는 단어 빈도에 따른 CER을 나타냅니다. 이는 훈련 세트에 없는 단어를 디코딩할 수 있는지 확인하기 위해,
# 미등록 단어(OOV) 디코딩을 사용하여 Brain2Qwerty가 훈련 세트에 없는 단어를 디코딩할 수 있는지 테스트한 결과입니다.
# C는 문자 빈도에 따른 CER을 나타냅니다.
# D는 훈련 세트에 포함된 기록 시간에 따른 CER을 나타냅니다.

# %% [markdown]
# ![image.png](attachment:f5be0f45-9427-4b55-abb0-457609eddb87.png)

# %% [markdown]
# A는 키보드 거리 효과를 분석한 것으로, 혼동률을 정규화된 키보드 거리와 비교한 결과입니다.
# B는 클러스터링 분석으로, 모델 임베딩을 K-평균 클러스터링을 사용하여
# 각각 2개(위)와 10개(아래) 클러스터로 나눈 결과를 나타냅니다.
# C는 키 누름 간격 분석으로, 올바른 키 누름과 타이핑 오류 간의 키 누름 간격을 비교하며,
# 앞선 문자와 그 이후 문자를 모두 고려한 결과입니다. 두 간격의 합이 표시됩니다.
# D는 타이핑 실수에 대한 성능 차이를 비교한 것으로, Conv+Trans 모델(왼쪽)과 Conv 모델(오른쪽)을 사용하여
# 올바른 문자와 타이핑 오류의 성능을 비교한 결과입니다.

# %% [markdown]
# ### 3. 브레인투쿼티의 특징 및 한계점

# %% [markdown]
# ![image.png](attachment:bd963498-bcf9-437f-9da8-ef6a7e3bd783.png)

# %% [markdown]
# Brain2Qwerty는 기존의 EEG 기반 뇌-컴퓨터 인터페이스(BCI)보다 뛰어난 성능을 보이며, 비침습적인 방식으로도 문장 해독이 가능하다는 점에서 중요한 연구 성과로 평가됩니다. 이 모델은 타이핑에 필요한 운동 패턴뿐만 아니라 언어적 요소를 뇌 신호에서 함께 반영하여 높은 정확도를 달성하는 것이 특징입니다. 이를 통해 뇌의 복잡한 신경 활동을 더 정교하게 분석하고, 문장 단위로 텍스트를 해석할 수 있는 가능성을 열었습니다. 기존의 EEG 기반 시스템이 주로 운동 활동만을 반영했던 것과 달리, Brain2Qwerty는 언어적 뉘앙스를 더 잘 포착할 수 있다는 장점이 있습니다.
#
# 하지만 여전히 해결해야 할 기술적 과제도 존재합니다. 현재 Brain2Qwerty의 가장 큰 한계는 실시간 처리의 어려움입니다. 이 모델은 문장 단위로 입력을 해석하는 방식이기 때문에 입력이 끝난 후에야 최종 문장이 출력됩니다. 이로 인해 실시간 타이핑처럼 즉각적인 반응을 요구하는 환경에서는 사용하기 어려운 측면이 있습니다. 따라서, 실시간 처리가 가능한 시스템으로 발전시키기 위한 기술적 진전이 필요합니다.
#
# 또한, MEG 장비는 크기가 크고(약 0.5톤), 강한 자기장이 필요해 일반적인 환경에서 쉽게 사용할 수 없는 점이 실용화의 장애 요소로 작용합니다. MEG 장비의 크기와 복잡성은 이를 상용화하고 널리 보급하는 데 있어 큰 제약으로 작용할 수 있습니다. 그럼에도 불구하고 Brain2Qwerty는 침습적 BCI와 비슷한 수준의 문장 해독 성능을 보이며, 향후 기술 발전을 통해 더욱 안전하고 효율적인 BCI 시스템 개발의 가능성을 열어주고 있습니다. 이 연구는 뇌-컴퓨터 인터페이스 분야의 중요한 이정표가 될 것으로 기대됩니다.

# %% [markdown]
# ### 4. BCI 시스템의 향후 전망

# %% [markdown]
# BCI 시스템은 향후 의료 분야에서 큰 혁신을 일으킬 것으로 예상됩니다.
# 특히, 신경학적 질환이나 신체 기능을 잃은 환자들에게 BCI 기술은 중요한 역할을 할 수 있습니다.
# 현재 BCI는 주로 뇌 신호를 기반으로 한 의사소통과 외부 장치 제어를 가능하게 하지만,
# 앞으로는 보다 정밀하고 개인화된 치료가 가능해질 것입니다.
# 이러한 기술은 척수 손상, 뇌졸중 후유증 등으로 인한 신체 장애를 극복하는 데 중요한 해결책을 제시할 수 있으며,
# 신경과학의 발전에 따라 환자 맞춤형 치료법이 개발될 것입니다.
# 또한, 비침습적 방식의 BCI가 더 발전하면서 신경 손상이나 감염 위험 없이
# 안전하게 사용할 수 있는 시스템이 확립될 것입니다.
#
# BCI의 실시간 처리 기술도 향후 큰 발전을 이루어낼 것입니다.
# 현재 대부분의 BCI 시스템은 뇌 신호를 분석하고 해석하는 데 시간이 걸려 실시간 상호작용에서 어려움을 겪고 있습니다.
# 하지만 향후 더욱 빠르고 효율적인 알고리즘과 하드웨어 개발로 실시간으로 뇌 신호를 처리하고
# 즉각적으로 반응하는 시스템이 가능해질 것입니다. 이를 통해 게임, 가상 현실, 증강 현실과 같은 분야에서
# 뇌파를 이용한 제어 방식이 더욱 정교해지고, 사용자 경험을 극대화하는 새로운 인터페이스가 등장할 것입니다.
# 또한, 실시간 분석 기술이 향상되면, 타이핑이나 커뮤니케이션에서 더 자연스럽고 효율적인 BCI 시스템이 구현될 것입니다.
#
# 그러나 BCI 기술의 상용화에는 여전히 여러 가지 기술적, 윤리적 도전 과제가 존재합니다.
# BCI 장치의 크기와 가격은 여전히 상용화를 제한하는 중요한 요소로 작용하고 있으며, 대부분의 장비는 크고 비쌉니다.
# 향후 기술 발전을 통해 더 작고, 저렴하면서도 고성능의 BCI 시스템이 개발되면 대중화가 이루어질 수 있을 것입니다.
# 또한, 뇌 신호를 읽고 해석하는 과정에서 개인정보 보호와 윤리적 문제가 제기될 수 있습니다.
# 개인의 뇌파 데이터가 어떻게 사용되고 보호될지에 대한 법적, 기술적 논의가 필요하며,
# 이를 해결하기 위한 연구가 병행되어야 합니다. BCI의 발전과 함께 윤리적인 논의와 규제도 중요해질 것입니다.

# %% [markdown]
# ###### 출처 :
# https://www.aitimes.com/news/articleView.html?idxno=167830
#
# https://www.digitaltoday.co.kr/news/articleView.html?idxno=552707
#
# https://www.irobotnews.com/news/articleView.html?idxno=25130
#
# https://scontent-gmp1-1.xx.fbcdn.net/v/t39.2365-6/475464888_600710912891423_9108680259802499048_n.pdf?_nc_cat=102&ccb=1-7&_nc_sid=3c67a6&_nc_ohc=skBEbLcNeccQ7kNvgFWHgi_&_nc_oc=AdiuLLUMZhRNfXLvQQEoUrzKSLFPq6G_qfkesd_6zXn7_XLqzgYbR-y_TCYdD4JQrA0&_nc_zt=14&_nc_ht=scontent-gmp1-1.xx&_nc_gid=ACuaYGuQItsB3jgzwe2lq1_&oh=00_AYALP32VkgVRcTVqqIwPQLhSNhYn_RNE8Suq8dEGII0Lxg&oe=67AF9096
#
# https://stibee.com/api/v1.0/emails/share/8U3s0eQRd6wHeczO_fyiKMIvXviL7A==
